# %% [markdown]
# # Star Trek on Wikidata
#
# Query Wikidata's SPARQL endpoint for Star Trek series, cast, and species data.
# Complements the STAPI-based notebook (`Star_Trek_API.ipynb`) with linked open data from Wikidata.
#
# ## Resources
#
# - [Wikidata SPARQL endpoint](https://query.wikidata.org/)
# - [Wikidata: Star Trek franchise (Q1092)](https://www.wikidata.org/wiki/Q1092)
# - [Wikidata: Star Trek fictional universe (Q908113)](https://www.wikidata.org/wiki/Q908113)
# - [Wikidata SPARQL examples](https://www.wikidata.org/wiki/Wikidata:SPARQL_query_service/queries/examples)

# %% [markdown]
# ## Setup

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.addCustomHttpHeader("User-Agent", "SF-Nexus-Webscraping/1.0")

def run_query(query_string):
    sparql.setQuery(query_string)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    rows = []
    for r in results["results"]["bindings"]:
        rows.append({k: v["value"] for k, v in r.items()})
    return pd.DataFrame(rows)

# %% [markdown]
# ---
#
# ## Query 1: Star Trek TV Series
#
# All TV series in the Star Trek franchise, with premiere dates and episode counts.

# %%
series_query = """
SELECT ?series ?seriesLabel ?startDate ?episodes WHERE {
  # ?series wdt:P31 wd:Q5398426 .         # instance of: television series
  # ?series wdt:P8345 wd:Q1092 .           # franchise: Star Trek
  OPTIONAL { ?series wdt:P580 ?startDate . }
  OPTIONAL { ?series wdt:P1113 ?episodes . }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
ORDER BY ?startDate
"""

series_df = run_query(series_query)
series_df

# %% [markdown]
# ## Query 2: Cast Members and Characters
#
# Actors who appeared in Star Trek TV series and the characters they played.

# %%
cast_query = """
SELECT ?seriesLabel ?actorLabel ?characterLabel WHERE {
  # ?series wdt:P31 wd:Q5398426 .
  # ?series wdt:P8345 wd:Q1092 .
  # ?series p:P161 ?castStatement .
  # ?castStatement ps:P161 ?actor .
  OPTIONAL { ?castStatement pq:P453 ?character . }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
ORDER BY ?seriesLabel ?actorLabel
"""

cast_df = run_query(cast_query)
print(f"{len(cast_df)} cast entries")
cast_df.head(20)

# %% [markdown]
# ## Query 3: Actors in Multiple Series
#
# Which actors appeared across more than one Star Trek series?

# %%
crossover_query = """
SELECT ?actorLabel (COUNT(DISTINCT ?series) AS ?seriesCount)
       (GROUP_CONCAT(DISTINCT ?seriesLabel; separator=", ") AS ?seriesList) WHERE {
  # ?series wdt:P31 wd:Q5398426 .
  # ?series wdt:P8345 wd:Q1092 .
  # ?series wdt:P161 ?actor .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" .
                          # ?series rdfs:label ?seriesLabel .
                          # ?actor rdfs:label ?actorLabel . }
}
GROUP BY ?actorLabel
HAVING (COUNT(DISTINCT ?series) > 1)
ORDER BY DESC(?seriesCount)
"""

crossover_df = run_query(crossover_query)
crossover_df

# %% [markdown]
# ## Query 4: Star Trek Species
#
# Fictional species from the Star Trek universe on Wikidata.

# %%
species_query = """
SELECT ?species ?speciesLabel ?speciesDescription WHERE {
  # ?species wdt:P31 wd:Q15632617 .       # instance of: fictional species
  # ?species wdt:P1080 wd:Q908113 .        # fictional universe: Star Trek
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
ORDER BY ?speciesLabel
"""

species_df = run_query(species_query)
print(f"{len(species_df)} Star Trek species on Wikidata")
species_df

# %% [markdown]
# ## Query 5: Star Trek Films
#
# All Star Trek feature films with release dates and directors.

# %%
films_query = """
SELECT ?film ?filmLabel ?releaseDate ?directorLabel WHERE {
  # ?film wdt:P31 wd:Q11424 .              # instance of: film
  # ?film wdt:P8345 wd:Q1092 .             # franchise: Star Trek
  OPTIONAL { ?film wdt:P577 ?releaseDate . }
  OPTIONAL { ?film wdt:P57 ?director . }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
ORDER BY ?releaseDate
"""

films_df = run_query(films_query)
films_df
